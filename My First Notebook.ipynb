# %% [markdown]
# # My First Notebook
#
# ## Learn Python with Colab
#
# **How to learn Python?**
#
#
#
# ```
# # This is formatted as code
# ```
#
# `a=5` is a equal to 5.

# %%
import numpy as np

# %%
a = 5
print (a)
# Out:
# 5

# %%
a
# Out:
# 5
